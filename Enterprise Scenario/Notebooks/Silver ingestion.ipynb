# %%
# %sql
CREATE DATABASE IF NOT EXISTS silver;
CREATE TABLE IF NOT EXISTS silver_logs (
    run_id STRING,
    table_name STRING,
    status STRING,
    processing_time TIMESTAMP,
    row_count INT,
    error_message STRING
)
USING delta;

# %%
from pyspark.sql.functions import *
import uuid
run_id = str(uuid.uuid4())
bronze_sales = spark.table("bronze.sales_raw")

# %%
#UTC Conversion and Currency Exchange 
silver_sales_clean = bronze_sales \
    .withColumnRenamed("ingestion_timestamp", "bronze_ingestion_timestamp") \
    .withColumn("silver_processing_timestamp", current_timestamp()) \
    .withColumn(
        "transaction_ts_utc",
        to_utc_timestamp(to_timestamp("transaction_timestamp"), "UTC")
    ) \
    .withColumn(
        "exchange_rate",
        when(col("currency") == "USD", 1.0)
        .when(col("currency") == "INR", 0.012)
        .when(col("currency") == "EUR", 1.1)
    ) \
    .withColumn(
        "total_amount_corrected",
        round(col("quantity") * col("unit_price") - col("discount"), 2)
    ) \
    .withColumn(
        "total_amount_usd",
        col("total_amount_corrected") * col("exchange_rate")
    )

# %%
silver_sales_dedup = silver_sales_clean.dropDuplicates(["transaction_id"])

# %%
valid_sales = silver_sales_dedup.filter(
    (col("quantity") > 0) &
    col("product_id").isNotNull() &
    col("store_id").isNotNull() &
    col("exchange_rate").isNotNull()
)
invalid_sales = silver_sales_dedup.subtract(valid_sales)

# %%
valid_sales.write.format("delta") \
    .mode("overwrite") \
    .saveAsTable("silver.sales")

invalid_sales.write.format("delta") \
    .mode("overwrite") \
    .saveAsTable("silver.sales_quarantine")

# %%
row_count = valid_sales.count()

spark.sql(f"""
INSERT INTO silver_logs
VALUES (
    "{run_id}",
    "silver.sales",
    "SUCCESS",
    current_timestamp(),
    {row_count},
    NULL
)
""")
# Out:
# DataFrame[num_affected_rows: bigint, num_inserted_rows: bigint]

# %%
run_id = str(uuid.uuid4())

products = spark.table("bronze.products_raw")

products.write.format("delta") \
    .mode("overwrite") \
    .saveAsTable("silver.products")

spark.sql(f"""
INSERT INTO silver_logs
VALUES (
    "{run_id}",
    "silver.products",
    "SUCCESS",
    current_timestamp(),
    {products.count()},
    NULL
)
""")
# Out:
# DataFrame[num_affected_rows: bigint, num_inserted_rows: bigint]

# %%
from pyspark.sql.functions import current_timestamp
import uuid
run_id = str(uuid.uuid4())
stores_bronze = spark.table("bronze.stores_raw")

# %%
# %sql
SELECT store_id, COUNT(*) AS cnt
FROM bronze.stores_raw
GROUP BY store_id
HAVING COUNT(*) > 1;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>store_id</th><th>cnt</th></tr></thead><tbody></tbody></table></div>

# %%
stores_clean = stores_bronze \
    .filter(col("store_id").isNotNull()) \
    .dropDuplicates(["store_id"]) \
    .withColumn("silver_processing_timestamp", current_timestamp())

# %%
stores_clean.write.format("delta") \
    .mode("overwrite") \
    .saveAsTable("silver.stores")

# %%
row_count = stores_clean.count()
spark.sql(f"""
INSERT INTO silver_logs
VALUES (
    "{run_id}",
    "silver.stores",
    "SUCCESS",
    current_timestamp(),
    {row_count},
    NULL
)
""")
# Out:
# DataFrame[num_affected_rows: bigint, num_inserted_rows: bigint]

# %%
# %sql
SELECT COUNT(*) FROM silver.sales;
SELECT COUNT(*) FROM silver.sales_quarantine;
SELECT COUNT(*) FROM silver.products;
SELECT COUNT(*) FROM silver.stores;
SELECT * FROM silver_logs;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>run_id</th><th>table_name</th><th>status</th><th>processing_time</th><th>row_count</th><th>error_message</th></tr></thead><tbody><tr><td>ee21b515-caf0-40f8-8391-6fc2d84f40d7</td><td>silver.products</td><td>SUCCESS</td><td>2025-12-23T17:48:00.681Z</td><td>200</td><td>null</td></tr><tr><td>94d937d6-aac2-49a9-bce9-c967ce8ecb89</td><td>silver.stores</td><td>SUCCESS</td><td>2025-12-23T17:51:23.382Z</td><td>50</td><td>null</td></tr><tr><td>1745cd07-5922-4249-b5d5-7690fe30d77d</td><td>silver.sales</td><td>SUCCESS</td><td>2025-12-23T17:47:40.859Z</td><td>419</td><td>null</td></tr></tbody></table></div>

# %%
# %sql
SELECT product_id, COUNT(*) AS cnt
FROM bronze.products_raw
GROUP BY product_id
HAVING COUNT(*) > 1;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_id</th><th>cnt</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
SELECT COUNT(*) AS null_product_id_count
FROM bronze.products_raw
WHERE product_id IS NULL;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>null_product_id_count</th></tr></thead><tbody><tr><td>0</td></tr></tbody></table></div>

# %%
# %sql
SELECT COUNT(*) AS silver_sales_count FROM silver.sales;
SELECT COUNT(*) AS quarantine_count FROM silver.sales_quarantine;
SELECT * FROM silver_logs WHERE table_name = 'silver.sales';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>run_id</th><th>table_name</th><th>status</th><th>processing_time</th><th>row_count</th><th>error_message</th></tr></thead><tbody><tr><td>1745cd07-5922-4249-b5d5-7690fe30d77d</td><td>silver.sales</td><td>SUCCESS</td><td>2025-12-23T17:47:40.859Z</td><td>419</td><td>null</td></tr><tr><td>94148c16-02d4-4c3f-b001-4f7834f81565</td><td>silver.sales</td><td>SUCCESS</td><td>2025-12-23T18:00:34.677Z</td><td>324</td><td>null</td></tr></tbody></table></div>

# %% [markdown]
# #Incremental logic

# %%
# %sql
CREATE TABLE IF NOT EXISTS silver_watermark (
    table_name STRING,
    last_processed_ts TIMESTAMP
)
USING delta;

# %%
# %sql
INSERT INTO silver_watermark
VALUES ('silver.sales', TIMESTAMP('1900-01-01 00:00:00'));
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import col

last_ts = (
    spark.table("silver_watermark")
    .filter(col("table_name") == "silver.sales")
    .select("last_processed_ts")
    .collect()[0][0]
)
print("Last processed timestamp:", last_ts)
# Out:
# Last processed timestamp: 1900-01-01 00:00:00

# %%
bronze_sales = spark.table("bronze.sales_raw")

# %%
incremental_bronze_sales = bronze_sales.filter(
    col("ingestion_timestamp") > last_ts
)

# %%
from pyspark.sql.functions import *
silver_sales_clean = (
    incremental_bronze_sales
    .withColumnRenamed("ingestion_timestamp", "bronze_ingestion_timestamp")
    .withColumn("silver_processing_timestamp", current_timestamp())
    .withColumn(
        "transaction_ts_utc",
        to_utc_timestamp(to_timestamp("transaction_timestamp"), "UTC")
    )
    .withColumn(
        "exchange_rate",
        when(col("currency") == "USD", 1.0)
        .when(col("currency") == "INR", 0.012)
        .when(col("currency") == "EUR", 1.1)
    )
    .withColumn(
        "total_amount_corrected",
        round(col("quantity") * col("unit_price") - col("discount"), 2)
    )
    .withColumn(
        "total_amount_usd",
        col("total_amount_corrected") * col("exchange_rate")
    )
)

# %%
silver_sales_dedup = silver_sales_clean.dropDuplicates(["transaction_id"])

valid_sales = silver_sales_dedup.filter(
    (col("quantity") > 0) &
    col("product_id").isNotNull() &
    col("store_id").isNotNull() &
    col("exchange_rate").isNotNull()
)

invalid_sales = silver_sales_dedup.subtract(valid_sales)

# %%
from delta.tables import DeltaTable

silver_sales_tbl = DeltaTable.forName(spark, "silver.sales")

silver_sales_tbl.alias("t").merge(
    valid_sales.alias("s"),
    "t.transaction_id = s.transaction_id"
).whenMatchedUpdateAll() \
 .whenNotMatchedInsertAll() \
 .execute()
# Out:
# DataFrame[num_affected_rows: bigint, num_updated_rows: bigint, num_deleted_rows: bigint, num_inserted_rows: bigint]

# %%
invalid_sales.write.format("delta") \
    .mode("append") \
    .saveAsTable("silver.sales_quarantine")

# %%
#Updates Watermark tables
new_max_ts = incremental_bronze_sales.agg(
    {"ingestion_timestamp": "max"}
).collect()[0][0]

spark.sql(f"""
UPDATE silver_watermark
SET last_processed_ts = TIMESTAMP('{new_max_ts}')
WHERE table_name = 'silver.sales'
""")
# Out:
# DataFrame[num_affected_rows: bigint]

# %%
import uuid
run_id = str(uuid.uuid4())
spark.sql(f"""
INSERT INTO silver_logs
VALUES (
    "{run_id}",
    "silver.sales_incremental",
    "SUCCESS",
    current_timestamp(),
    {valid_sales.count()},
    NULL
)
""")
# Out:
# DataFrame[num_affected_rows: bigint, num_inserted_rows: bigint]
