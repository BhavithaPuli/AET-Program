# %%
#1.Ingest sample order data into a Spark DataFrame.
#used kaggle and found the dataset then modified as per requirement
from pyspark.sql.types import *
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
#/Volumes/chubb/default/deltalake/ShopEZ_orders.csv
spark = SparkSession.builder.appName("ShopEZ").getOrCreate()
# Loading shopesz dataset
df = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load("/Volumes/chubb/default/deltalake/ShopEZ_orders.csv")
df.show(5)
df.printSchema()
# Out:
# +---------+-------------------+-----------+-------+--------+-------+-------+
# | order_id|    order_timestamp|customer_id|country|currency| amount| status|
# +---------+-------------------+-----------+-------+--------+-------+-------+
# |ORD100000|2023-05-12 14:23:45|   CUST1863|     CA|     CAD|4937.69|CREATED|
# |ORD100001|2023-11-26 01:45:42|   CUST7805|     UK|     GBP|3138.91|CREATED|
# |ORD100002|2024-04-23 03:53:06|   CUST5839|     AU|     AUD|1018.75|   PAID|
# |ORD100003|2023-12-10 05:00:38|   CUST4763|     CA|     CAD|1395.14|   PAID|
# |ORD100004|2023-06-05 02:15:41|   CUST5409|     IN|     INR|1174.63|CREATED|
# +---------+-------------------+-----------+-------+--------+-------+-------+
# only showing top 5 rows
# root
#  |-- order_id: string (nullable = true)
#  |-- order_timestamp: timestamp (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- currency: string (nullable = true)
#  |-- amount: double (nullable = true)
#  |-- status: string (nullable = true)

# %%
#2.Adding a derived column called order_date using order_timestamp
#extracts year-month-day 
df=df.withColumn("order_date", to_date(col("order_timestamp")))
df.show(5)
df.printSchema()
# Out:
# +---------+-------------------+-----------+-------+--------+-------+-------+----------+
# | order_id|    order_timestamp|customer_id|country|currency| amount| status|order_date|
# +---------+-------------------+-----------+-------+--------+-------+-------+----------+
# |ORD100000|2023-05-12 14:23:45|   CUST1863|     CA|     CAD|4937.69|CREATED|2023-05-12|
# |ORD100001|2023-11-26 01:45:42|   CUST7805|     UK|     GBP|3138.91|CREATED|2023-11-26|
# |ORD100002|2024-04-23 03:53:06|   CUST5839|     AU|     AUD|1018.75|   PAID|2024-04-23|
# |ORD100003|2023-12-10 05:00:38|   CUST4763|     CA|     CAD|1395.14|   PAID|2023-12-10|
# |ORD100004|2023-06-05 02:15:41|   CUST5409|     IN|     INR|1174.63|CREATED|2023-06-05|
# +---------+-------------------+-----------+-------+--------+-------+-------+----------+
# only showing top 5 rows
# root
#  |-- order_id: string (nullable = true)
#  |-- order_timestamp: timestamp (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- currency: string (nullable = true)
#  |-- amount: double (nullable = true)
#  |-- status: string (nullable = true)
#  |-- order_date: date (nullable = true)

# %%
#3.Write the DataFrame as a Delta table partitioned by country and order_date
# Write dataframe as delta table
# Partition by country and order_date
# Save as managed delta table
df.write.format("delta") \
    .mode("overwrite") \
    .partitionBy("country", "order_date") \
    .saveAsTable("chubb.default.orders")

# %%
#4.Verify the partition structure in the storage path.
#Unity Catalog managed tables ALWAYS show location as null
display(spark.sql("DESCRIBE DETAIL chubb.default.orders"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>format</th><th>id</th><th>name</th><th>description</th><th>location</th><th>createdAt</th><th>lastModified</th><th>partitionColumns</th><th>clusteringColumns</th><th>numFiles</th><th>sizeInBytes</th><th>properties</th><th>minReaderVersion</th><th>minWriterVersion</th><th>tableFeatures</th><th>statistics</th><th>clusterByAuto</th></tr></thead><tbody><tr><td>delta</td><td>b36fa122-9391-4443-b0ac-f2b51b255c67</td><td>chubb.default.orders</td><td>null</td><td></td><td>2025-12-01T17:10:29.243Z</td><td>2025-12-01T17:11:31.000Z</td><td>List(country, order_date)</td><td>List()</td><td>3455</td><td>6365722</td><td>Map(delta.enableDeletionVectors -> true)</td><td>3</td><td>7</td><td>List(appendOnly, deletionVectors, invariants)</td><td>Map(numRowsDeletedByDeletionVectors -> 0, numDeletionVectors -> 0)</td><td>false</td></tr></tbody></table></div>

# %%
# %sql
-- Show table partitions as unity catalog is on
SHOW PARTITIONS chubb.default.orders;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>country</th><th>order_date</th></tr></thead><tbody><tr><td>UK</td><td>2024-01-30</td></tr><tr><td>AU</td><td>2023-05-31</td></tr><tr><td>UK</td><td>2023-07-05</td></tr><tr><td>UK</td><td>2024-07-25</td></tr><tr><td>UK</td><td>2023-03-18</td></tr><tr><td>CA</td><td>2024-10-12</td></tr><tr><td>UK</td><td>2023-05-22</td></tr><tr><td>CA</td><td>2024-04-25</td></tr><tr><td>UK</td><td>2023-10-10</td></tr><tr><td>US</td><td>2024-07-03</td></tr><tr><td>US</td><td>2024-01-19</td></tr><tr><td>IN</td><td>2024-01-06</td></tr><tr><td>CA</td><td>2023-08-30</td></tr><tr><td>IN</td><td>2024-11-27</td></tr><tr><td>US</td><td>2024-05-21</td></tr><tr><td>UK</td><td>2024-08-28</td></tr><tr><td>CA</td><td>2024-08-19</td></tr><tr><td>AU</td><td>2024-12-07</td></tr><tr><td>UK</td><td>2023-05-10</td></tr><tr><td>AU</td><td>2023-02-17</td></tr><tr><td>AU</td><td>2023-04-14</td></tr><tr><td>IN</td><td>2024-08-02</td></tr><tr><td>IN</td><td>2024-10-14</td></tr><tr><td>AU</td><td>2023-08-29</td></tr><tr><td>US</td><td>2023-01-02</td></tr><tr><td>UK</td><td>2024-09-16</td></tr><tr><td>CA</td><td>2023-08-18</td></tr><tr><td>AU</td><td>2023-02-14</td></tr><tr><td>IN</td><td>2024-11-14</td></tr><tr><td>UK</td><td>2024-06-02</td></tr><tr><td>IN</td><td>2024-04-18</td></tr><tr><td>AU</td><td>2024-01-25</td></tr><tr><td>CA</td><td>2024-12-19</td></tr><tr><td>UK</td><td>2024-08-12</td></tr><tr><td>US</td><td>2024-05-18</td></tr><tr><td>AU</td><td>2023-12-30</td></tr><tr><td>AU</td><td>2024-03-25</td></tr><tr><td>CA</td><td>2023-04-04</td></tr><tr><td>US</td><td>2023-05-07</td></tr><tr><td>UK</td><td>2023-09-21</td></tr><tr><td>US</td><td>2023-10-21</td></tr><tr><td>CA</td><td>2024-09-28</td></tr><tr><td>CA</td><td>2023-09-02</td></tr><tr><td>AU</td><td>2024-07-12</td></tr><tr><td>US</td><td>2023-12-12</td></tr><tr><td>CA</td><td>2024-05-26</td></tr><tr><td>CA</td><td>2024-03-28</td></tr><tr><td>IN</td><td>2024-02-24</td></tr><tr><td>CA</td><td>2023-03-22</td></tr><tr><td>CA</td><td>2023-08-23</td></tr><tr><td>AU</td><td>2023-10-16</td></tr><tr><td>AU</td><td>2024-12-04</td></tr><tr><td>CA</td><td>2023-11-01</td></tr><tr><td>UK</td><td>2024-02-05</td></tr><tr><td>UK</td><td>2024-11-23</td></tr><tr><td>UK</td><td>2023-05-20</td></tr><tr><td>AU</td><td>2024-02-21</td></tr><tr><td>UK</td><td>2023-07-08</td></tr><tr><td>CA</td><td>2024-11-22</td></tr><tr><td>US</td><td>2024-07-12</td></tr><tr><td>IN</td><td>2023-03-25</td></tr><tr><td>AU</td><td>2024-05-02</td></tr><tr><td>IN</td><td>2023-06-12</td></tr><tr><td>IN</td><td>2023-08-14</td></tr><tr><td>CA</td><td>2023-04-18</td></tr><tr><td>CA</td><td>2023-03-27</td></tr><tr><td>AU</td><td>2024-07-24</td></tr><tr><td>AU</td><td>2023-05-16</td></tr><tr><td>CA</td><td>2023-10-02</td></tr><tr><td>CA</td><td>2024-01-22</td></tr><tr><td>AU</td><td>2023-07-04</td></tr><tr><td>CA</td><td>2024-11-10</td></tr><tr><td>AU</td><td>2023-10-26</td></tr><tr><td>AU</td><td>2024-02-27</td></tr><tr><td>US</td><td>2024-08-09</td></tr><tr><td>UK</td><td>2024-05-23</td></tr><tr><td>IN</td><td>2024-12-11</td></tr><tr><td>CA</td><td>2024-07-02</td></tr><tr><td>US</td><td>2024-03-09</td></tr><tr><td>IN</td><td>2023-12-06</td></tr><tr><td>IN</td><td>2023-05-08</td></tr><tr><td>IN</td><td>2023-02-27</td></tr><tr><td>CA</td><td>2024-04-17</td></tr><tr><td>UK</td><td>2024-08-16</td></tr><tr><td>IN</td><td>2023-04-04</td></tr><tr><td>AU</td><td>2024-09-11</td></tr><tr><td>CA</td><td>2023-11-30</td></tr><tr><td>CA</td><td>2023-08-04</td></tr><tr><td>US</td><td>2024-01-14</td></tr><tr><td>AU</td><td>2023-09-06</td></tr><tr><td>UK</td><td>2023-04-29</td></tr><tr><td>UK</td><td>2024-02-19</td></tr><tr><td>AU</td><td>2023-12-04</td></tr><tr><td>IN</td><td>2023-08-27</td></tr><tr><td>AU</td><td>2024-04-16</td></tr><tr><td>US</td><td>2023-11-28</td></tr><tr><td>IN</td><td>2023-03-14</td></tr><tr><td>CA</td><td>2024-07-26</td></tr><tr><td> ...

# %%
## Run sql to show partitions
spark.sql("SHOW PARTITIONS chubb.default.orders").show(truncate=False)
# If truncate is false then it displays full output without truncation
# Out:
# +-------+----------+
# |country|order_date|
# +-------+----------+
# |UK     |2024-01-30|
# |AU     |2023-05-31|
# |UK     |2023-07-05|
# |UK     |2024-07-25|
# |UK     |2023-03-18|
# |CA     |2024-10-12|
# |UK     |2023-05-22|
# |CA     |2024-04-25|
# |UK     |2023-10-10|
# |US     |2024-07-03|
# |US     |2024-01-19|
# |IN     |2024-01-06|
# |CA     |2023-08-30|
# |IN     |2024-11-27|
# |US     |2024-05-21|
# |UK     |2024-08-28|
# |CA     |2024-08-19|
# |AU     |2024-12-07|
# |UK     |2023-05-10|
# |AU     |2023-02-17|
# +-------+----------+
# only showing top 20 rows

# %%
#5.Run queries that demonstrate partition pruning
# Read delta table using table name
df_delta = spark.table("chubb.default.orders")
# 1.Filter by country to prune partitions
df_delta.filter(col("country") == "IN").show()
# 2.Filter by order_date to prune date partitions
df_delta.filter(col("order_date") == "2024-01-15").show()
# 3.Filter by both country and date to prune more partitions
df_delta.filter(
    (col("country") == "US") &
    (col("order_date") == "2024-01-20")
).show()
# 4.Count rows after pruning
df_delta.filter(col("country") == "UK") \
    .groupBy("country", "order_date") \
    .count() \
    .show()
# Out:
# +---------+-------------------+-----------+-------+--------+-------+---------+----------+
# | order_id|    order_timestamp|customer_id|country|currency| amount|   status|order_date|
# +---------+-------------------+-----------+-------+--------+-------+---------+----------+
# |ORD106074|2023-03-27 03:41:37|   CUST2255|     IN|     INR|1053.78|CANCELLED|2023-03-27|
# |ORD104604|2023-03-27 06:14:47|   CUST5982|     IN|     INR|1235.16|CANCELLED|2023-03-27|
# |ORD103695|2023-03-27 23:35:44|   CUST2841|     IN|     INR| 572.71|CANCELLED|2023-03-27|
# |ORD101791|2023-03-27 11:31:46|   CUST6104|     IN|     INR|1071.53|  CREATED|2023-03-27|
# |ORD100987|2023-03-27 16:10:14|   CUST7716|     IN|     INR|4722.76|CANCELLED|2023-03-27|
# |ORD109946|2023-05-18 12:01:20|   CUST8371|     IN|     INR|3490.06|CANCELLED|2023-05-18|
# |ORD103629|2023-05-18 00:18:40|   CUST8453|     IN|     INR|3121.65|CANCELLED|2023-05-18|
# |ORD102739|2023-05-18 11:47:01|   CUST5274|     IN|     INR|2884.98|     PAID|2023-05-18|
# |ORD101595|2023-05-18 12:43:46|   CUST1955|     IN|     INR|4236.83|CANCELLED|2023-05-18|
# |ORD105735|2023-01-21 05:56:53|   CUST9226|     IN|     INR|2510.69|  CREATED|2023-01-21|
# |ORD102842|2023-01-21 06:55:52|   CUST9895|     IN|     INR|4827.23|CANCELLED|2023-01-21|
# |ORD102333|2023-01-21 19:07:15|   CUST3016|     IN|     INR|3749.85|  CREATED|2023-01-21|
# |ORD100971|2023-11-11 22:37:37|   CUST5094|     IN|     INR|1914.98|CANCELLED|2023-11-11|
# |ORD102968|2023-11-11 09:07:21|   CUST5834|     IN|     INR| 577.84|     PAID|2023-11-11|
# |ORD106205|2023-11-11 10:26:29|   CUST8631|     IN|     INR| 482.87|  CREATED|2023-11-11|
# |ORD107808|2023-07-05 12:16:04|   CUST2160|     IN|     INR|2299.91|  CREATED|2023-07-05|
# |ORD106214|2023-07-05 12:18:15|   CUST9089|     IN|     INR|1672.02|CANCELLED|2023-07-05|
# |ORD103864|2023-09-23 22:02:00|   CUST8732|     IN|     INR|3087.68|  CREATED|2023-09-23|
# |ORD104268|2023-09-23 08:17:45|   CUST9865|     IN|     INR|1087.86|CANCELLED|2023-09-23|
# |ORD105040|2023-10-29 01:32:32|   CUST3914|     IN|     INR|2604.23|CANCELLED|2023-10-29|
# +---------+-------------------+-----------+-------+--------+-------+---------+----------+
# only showing top 20 rows
# +---------+-------------------+-----------+-------+--------+-------+---------+----------+
# | order_id|    order_timestamp|customer_id|country|currency| amount|   status|order_date|
# +---------+-------------------+-----------+-------+--------+-------+---------+----------+
# |ORD101824|2024-01-15 04:04:17|   CUST4174|     IN|     INR|1410.38|     PAID|2024-01-15|
# |ORD100982|2024-01-15 12:45:08|   CUST8488|     IN|     INR|4443.55|CANCELLED|2024-01-15|
# |ORD100733|2024-01-15 20:25:40|   CUST3990|     IN|     INR|2435.37|  CREATED|2024-01-15|
# |ORD104091|2024-01-15 13:12:19|   CUST4767|     US|     USD|4752.64|CANCELLED|2024-01-15|
# |ORD100738|2024-01-15 13:52:36|   CUST8508|     US|     USD|2204.75|  CREATED|2024-01-15|
# |ORD107216|2024-01-15 12:50:58|   CUST1149|     UK|     GBP| 797.85|  CREATED|2024-01-15|
# |ORD109624|2024-01-15 23:52:30|   CUST6883|     UK|     GBP|2022.16|     PAID|2024-01-15|
# |ORD106591|2024-01-15 00:25:08|   CUST9418|     AU|     AUD|1795.81|CANCELLED|2024-01-15|
# +---------+-------------------+-----------+-------+--------+-------+---------+----------+
#
# +---------+-------------------+-----------+-------+--------+-------+---------+----------+
# | order_id|    order_timestamp|customer_id|country|currency| amount|   status|order_date|
# +---------+-------------------+-----------+-------+--------+-------+---------+----------+
# |ORD108251|2024-01-20 06:16:39|   CUST6996|     US|     USD|3578.05|  CREATED|2024-01-20|
# |ORD108181|2024-01-20 04:56:39|   CUST6308|     US|     USD| 841.74|CANCELLED|2024-01-20|
# |ORD106096|2024-01-20 08:07:04|   CUST3274|     US|     USD|3393.83|     PAID|2024-01-20|
# |ORD101213|2024-01-20 03:27:51|   CUST7906|     US|     USD| 634.62|CANCELLED|2024-01-20|
# +---------+-------------------+-----------+-------+--------+-------+---------+----------+
#
# +-------+----------+-----+
# |country|order_date|count|
# +-------+----------+-----+
# |     UK|2024-08-09|    3|
# |     UK|2024-08-26|    1|
# |     UK|2023-10-02|    1|
# |     UK|2023-05-10|    3|
# |     UK|2024-05-25|    2|
# |     UK|2024-11-21|    2|
# |     UK|2023-01-21|    1|
# |     UK|2024-05-27|    4|
# |     UK|2024-12-22|    1|
# |     UK|2024-09-18|    2|
# |     UK|2023-09-16|    1|
# |     UK|2023-06-03|    6|
# |     UK|2024-04-12|    2|
# |     UK|2023-10-29|    5|
# |     UK|2024-01-24|    6|
# |     UK|2023-04-04|    3|
# |     UK|2024-03-16|    5|
# |     UK|2023-12-17|    2|
# |     UK|2024-11-14|    8|
# |     UK|2024-05-23|    3|
# +-------+----------+-----+
# only showing top 20 rows

# %%
spark.sql("DESCRIBE DETAIL chubb.default.orders").show(truncate=False)
# Out:
# +------+------------------------------------+--------------------+-----------+--------+-----------------------+-------------------+---------------------+-----------------+--------+-----------+-------------------------------------+----------------+----------------+-----------------------------------------+---------------------------------------------------------------+-------------+
# |format|id                                  |name                |description|location|createdAt              |lastModified       |partitionColumns     |clusteringColumns|numFiles|sizeInBytes|properties                           |minReaderVersion|minWriterVersion|tableFeatures                            |statistics                                                     |clusterByAuto|
# +------+------------------------------------+--------------------+-----------+--------+-----------------------+-------------------+---------------------+-----------------+--------+-----------+-------------------------------------+----------------+----------------+-----------------------------------------+---------------------------------------------------------------+-------------+
# |delta |b36fa122-9391-4443-b0ac-f2b51b255c67|chubb.default.orders|NULL       |        |2025-12-01 17:10:29.243|2025-12-01 17:11:31|[country, order_date]|[]               |3455    |6365722    |{delta.enableDeletionVectors -> true}|3               |7               |[appendOnly, deletionVectors, invariants]|{numRowsDeletedByDeletionVectors -> 0, numDeletionVectors -> 0}|false        |
# +------+------------------------------------+--------------------+-----------+--------+-----------------------+-------------------+---------------------+-----------------+--------+-----------+-------------------------------------+----------------+----------------+-----------------------------------------+---------------------------------------------------------------+-------------+

# %%
# Importing the DeltaTable class to work with existing Delta tables
from delta.tables import DeltaTable
# Load the Delta table using the given name
delta= DeltaTable.forName(spark, "chubb.default.orders")
# Display the transaction history of the Delta table
# Each entry includes version number, operation type timestamp, user info, and other metadata. Useful for auditing and debugging.
delta.history().show(truncate=False)
# Out:
# +-------+-------------------+--------------+-----------------------+---------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----+-----------------+------------------------+-----------+-----------------+-------------+-------------------------------------------------------------------------------------------------------------------------------------------------+------------+--------------------------------------------------+
# |version|timestamp          |userId        |userName               |operation                        |operationParameters                                                                                                                                                          |job |notebook         |clusterId               |readVersion|isolationLevel   |isBlindAppend|operationMetrics                                                                                                                                 |userMetadata|engineInfo                                        |
# +-------+-------------------+--------------+-----------------------+---------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----+-----------------+------------------------+-----------+-----------------+-------------+-------------------------------------------------------------------------------------------------------------------------------------------------+------------+--------------------------------------------------+
# |0      |2025-12-01 17:11:31|72975796256166|bhavithapuli4@gmail.com|CREATE OR REPLACE TABLE AS SELECT|{partitionBy -> ["country","order_date"], clusterBy -> [], description -> NULL, isManaged -> true, properties -> {"delta.enableDeletionVectors":"true"}, statsOnLoad -> true}|NULL|{875025030094014}|1201-160601-a4ipi6n5-v2n|NULL       |WriteSerializable|false        |{numFiles -> 3455, numRemovedFiles -> 0, numRemovedBytes -> 0, numDeletionVectorsRemoved -> 0, numOutputRows -> 10000, numOutputBytes -> 6365722}|NULL        |Databricks-Runtime/17.2.x-aarch64-photon-scala2.13|
# +-------+-------------------+--------------+-----------------------+---------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----+-----------------+------------------------+-----------+-----------------+-------------+-------------------------------------------------------------------------------------------------------------------------------------------------+------------+--------------------------------------------------+

# %%
spark.sql("""
SELECT *
FROM chubb.default.orders
WHERE country = 'IN'
""").explain(extended=True)
# Out:
# == Parsed Logical Plan ==
# 'Project [*]
# +- 'Filter ('country = IN)
#    +- 'UnresolvedRelation [chubb, default, orders], [], false
#
# == Analyzed Logical Plan ==
# order_id: string, order_timestamp: timestamp, customer_id: string, country: string, currency: string, amount: double, status: string, order_date: date, payment_method: string, coupon_code: string
# Project [order_id#46479, order_timestamp#46480, customer_id#46481, country#46482, currency#46483, amount#46484, status#46485, order_date#46486, payment_method#46487, coupon_code#46488]
# +- Filter (country#46482 = IN)
#    +- SubqueryAlias chubb.default.orders
#       +- Relation chubb.default.orders[order_id#46479,order_timestamp#46480,customer_id#46481,country#46482,currency#46483,amount#46484,status#46485,order_date#46486,payment_method#46487,coupon_code#46488] parquet
#
# == Optimized Logical Plan ==
# Filter (isnotnull(country#46482) AND (country#46482 = IN))
# +- Relation chubb.default.orders[order_id#46479,order_timestamp#46480,customer_id#46481,country#46482,currency#46483,amount#46484,status#46485,order_date#46486,payment_method#46487,coupon_code#46488] parquet
#
# == Physical Plan ==
# *(1) ColumnarToRow
# +- PhotonResultStage
#    +- PhotonProject [order_id#46479, order_timestamp#46480, customer_id#46481, country#46482, currency#46483, amount#46484, status#46485, order_date#46486, payment_method#46487, coupon_code#46488]
#       +- PhotonScan parquet chubb.default.orders[order_id#46479,order_timestamp#46480,customer_id#46481,currency#46483,amount#46484,status#46485,payment_method#46487,coupon_code#46488,country#46482,order_date#46486] DataFilters: [], DictionaryFilters: [], Format: parquet, Location: PreparedDeltaFileIndex(1 paths)[s3://dbstorage-prod-0b6lk/uc/3d362983-8e62-4dfc-bba8-5283ab5661a7..., OptionalDataFilters: [], PartitionFilters: [isnotnull(country#46482), (country#46482 = IN)], ReadSchema: struct<order_id:string,order_timestamp:timestamp,customer_id:string,currency:string,amount:double..., RequiredDataFilters: []
#
# == Photon Explanation ==
# The query is fully supported by Photon.
# == Optimizer Statistics (table names per statistics state) ==
#   missing =
#   partial = orders
#   full    =
# Corrective actions: consider running the following command on all tables with missing or partial statistics
#   ANALYZE TABLE <table-name> COMPUTE STATISTICS FOR ALL COLUMNS

# %%
# %sql
ANALYZE TABLE chubb.default.orders COMPUTE STATISTICS FOR ALL COLUMNS;

# %%
# Task - 6 : Demonstrate Delta Lake Time Travel
from delta.tables import DeltaTable

# Load the Delta table using the table name.
# Unity Catalog managed tables use forName() instead of forPath().
dt = DeltaTable.forName(spark, "chubb.default.orders")
# Show the transaction history of the Delta table.
# Each entry contains version number, timestamp, read/write info,
# operation type (WRITE, UPDATE), and useful metadata.
dt.history().show(truncate=False)
# Update rows in the Delta table where status = 'CREATED'
# This will change those rows to 'PAID' and create a new version.
dt.update(
    condition="status = 'CREATED'",
    set={"status": "'PAID'"}
)
# Show history again after the update
dt.history().show(truncate=False)
# TIME TRAVEL: Read an older version of the table
# versionAsOf = 0 loads the very first version of the table
old_df = spark.read \
    .option("versionAsOf", 0) \
    .table("chubb.default.orders")
old_df.show(truncate=False)
# Read the current/latest version of the Delta table
current_df = spark.table("chubb.default.orders")

current_df.show(truncate=False)
# Out:
# +-------+-------------------+--------------+-----------------------+---------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |version|timestamp          |userId        |userName               |operation|operationParameters                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# +-------+-------------------+--------------+-----------------------+---------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |25     |2025-12-01 17:34:56|72975796256166|bhavithapuli4@gmail.com|OPTIMIZE |{clusterBy -> [], zOrderBy -> [], batchId -> 0, predicate -> ["((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((('country <=> cast(CA as string)) AND ('order_date <=> cast(2023-12-27 as date))) OR (('country <=> cast(IN as string)) AND ('order_date <=> cast(2024-06-12 as date)))) OR (('country <=> cast(IN as string)) AND ('order_date <=> cast(2023-10-13 as date)))) OR (('country <=> cast(IN as string)) AND ('order_date <=> cast(2023-08-07 as date)))) OR (('country <=> cast(UK as string)) AND ('order_date <=> cast(2024-12-20 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2024-08-23 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2023-02-07 as date)))) OR (('country <=> cast(AU as string)) AND ('order_date <=> cast(2024-07-13 as date)))) OR (('country <=> cast(IN as string)) AND ('order_date <=> cast(2023-06-08 as date)))) OR (('country <=> cast(IN as string)) AND ('order_date <=> cast(2024-01-19 as date)))) OR (('country <=> cast(UK as string)) AND ('order_date <=> cast(2024-02-17 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2023-03-30 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2024-07-18 as date)))) OR (('country <=> cast(US as string)) AND ('order_date <=> cast(2023-07-12 as date)))) OR (('country <=> cast(US as string)) AND ('order_date <=> cast(2023-09-04 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2023-07-22 as date)))) OR (('country <=> cast(US as string)) AND ('order_date <=> cast(2023-07-07 as date)))) OR (('country <=> cast(AU as string)) AND ('order_date <=> cast(2024-12-15 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2023-04-05 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2024-09-26 as date)))) OR (('country <=> cast(IN as string)) AND ('order_date <=> cast(2023-04-13 as date)))) OR (('country <=> cast(AU as string)) AND ('order_date <=> cast(2024-04-16 as date)))) OR (('country <=> cast(IN as string)) AND ('order_date <=> cast(2023-04-05 as date)))) OR (('country <=> cast(AU as string)) AND ('order_date <=> cast(2024-01-14 as date)))) OR (('country <=> cast(US as string)) AND ('order_date <=> cast(2024-04-09 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2024-09-29 as date)))) OR (('country <=> cast(AU as string)) AND ('order_date <=> cast(2023-03-29 as date)))) OR (('country <=> cast(UK as string)) AND ('order_date <=> cast(2024-12-26 as date)))) OR (('country <=> cast(US as string)) AND ('order_date <=> cast(2024-08-02 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2024-03-03 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2023-05-31 as date)))) OR (('country <=> cast(AU as string)) AND ('order_date <=> cast(2024-07-06 as date)))) OR (('country <=> cast(AU as string)) AND ('order_date <=> cast(2023-10-04 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2023-11-14 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2024-09-23 as date)))) OR (('country <=> cast(IN as string)) AND ('order_date <=> cast(2023-10-06 as date)))) OR (('country <=> cast(IN as string)) AND ('order_date <=> cast(2023-05-31 as date)))) OR (('country <=> cast(US as string)) AND ('order_date <=> cast(2024-11-07 as date)))) OR (('country <=> cast(US as string)) AND ('order_date <=> cast(2024-02-18 as date)))) OR (('country <=> cast(US as string)) AND ('order_date <=> cast(2024-04-17 as date)))) OR (('country <=> cast(UK as string)) AND ('order_date <=> cast(2023-10-23 as date)))) OR (('country <=> cast(IN as string)) AND ('order_date <=> cast(2024-02-22 as date)))) OR (('country <=> cast(UK as string)) AND ('order_date <=> cast(2023-05-23 as date)))) OR (('country <=> cast(UK as string)) AND ('order ...
# |24     |2025-12-01 17:34:50|72975796256166|bhavithapuli4@gmail.com|UPDATE   |{predicate -> ["(amount#36920 < 50.0)"]}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# |23     |2025-12-01 17:31:56|72975796256166|bhavithapuli4@gmail.com|OPTIMIZE |{clusterBy -> [], zOrderBy -> [], batchId -> 0, predicate -> ["((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((('country <=> cast(CA as string)) AND ('order_date <=> cast(2023-12-27 as date))) OR (('country <=> cast(IN as string)) AND ('order_date <=> cast(2024-06-12 as date)))) OR (('country <=> cast(IN as string)) AND ('order_date <=> cast(2023-10-13 as date)))) OR (('country <=> cast(IN as string)) AND ('order_date <=> cast(2023-08-07 as date)))) OR (('country <=> cast(UK as string)) AND ('order_date <=> cast(2024-12-20 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2024-08-23 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2023-02-07 as date)))) OR (('country <=> cast(AU as string)) AND ('order_date <=> cast(2024-07-13 as date)))) OR (('country <=> cast(IN as string)) AND ('order_date <=> cast(2023-06-08 as date)))) OR (('country <=> cast(IN as string)) AND ('order_date <=> cast(2024-01-19 as date)))) OR (('country <=> cast(UK as string)) AND ('order_date <=> cast(2024-02-17 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2023-03-30 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2024-07-18 as date)))) OR (('country <=> cast(US as string)) AND ('order_date <=> cast(2023-07-12 as date)))) OR (('country <=> cast(US as string)) AND ('order_date <=> cast(2023-09-04 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2023-07-22 as date)))) OR (('country <=> cast(US as string)) AND ('order_date <=> cast(2023-07-07 as date)))) OR (('country <=> cast(AU as string)) AND ('order_date <=> cast(2024-12-15 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2023-04-05 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2024-09-26 as date)))) OR (('country <=> cast(IN as string)) AND ('order_date <=> cast(2023-04-13 as date)))) OR (('country <=> cast(AU as string)) AND ('order_date <=> cast(2024-04-16 as date)))) OR (('country <=> cast(IN as string)) AND ('order_date <=> cast(2023-04-05 as date)))) OR (('country <=> cast(AU as string)) AND ('order_date <=> cast(2024-01-14 as date)))) OR (('country <=> cast(US as string)) AND ('order_date <=> cast(2024-04-09 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2024-09-29 as date)))) OR (('country <=> cast(AU as string)) AND ('order_date <=> cast(2023-03-29 as date)))) OR (('country <=> cast(UK as string)) AND ('order_date <=> cast(2024-12-26 as date)))) OR (('country <=> cast(US as string)) AND ('order_date <=> cast(2024-08-02 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2024-03-03 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2023-05-31 as date)))) OR (('country <=> cast(AU as string)) AND ('order_date <=> cast(2024-07-06 as date)))) OR (('country <=> cast(AU as string)) AND ('order_date <=> cast(2023-10-04 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2023-11-14 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2024-09-23 as date)))) OR (('country <=> cast(IN as string)) AND ('order_date <=> cast(2023-10-06 as date)))) OR (('country <=> cast(IN as string)) AND ('order_date <=> cast(2023-05-31 as date)))) OR (('country <=> cast(US as string)) AND ('order_date <=> cast(2024-11-07 as date)))) OR (('country <=> cast(US as string)) AND ('order_date <=> cast(2024-02-18 as date)))) OR (('country <=> cast(US as string)) AND ('order_date <=> cast(2024-04-17 as date)))) OR (('country <=> cast(UK as string)) AND ('order_date <=> cast(2023-10-23 as date)))) OR (('country <=> cast(IN as string)) AND ('order_date <=> cast(2024-02-22 as date)))) OR (('country <=> cast(UK as string)) AND ('order_date <=> cast(2023-05-23 as date)))) OR (('country <=> cast(UK as string)) AND ('order ...
# |22     |2025-12-01 17:31:52|72975796256166|bhavithapuli4@gmail.com|UPDATE   |{predicate -> ["(amount#35054 < 50.0)"]}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# |21     |2025-12-01 17:29:03|72975796256166|bhavithapuli4@gmail.com|OPTIMIZE |{clusterBy -> [], zOrderBy -> [], batchId -> 0, predicate -> ["((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((('country <=> cast(CA as string)) AND ('order_date <=> cast(2023-12-27 as date))) OR (('country <=> cast(IN as string)) AND ('order_date <=> cast(2024-06-12 as date)))) OR (('country <=> cast(IN as string)) AND ('order_date <=> cast(2023-10-13 as date)))) OR (('country <=> cast(IN as string)) AND ('order_date <=> cast(2023-08-07 as date)))) OR (('country <=> cast(UK as string)) AND ('order_date <=> cast(2024-12-20 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2024-08-23 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2023-02-07 as date)))) OR (('country <=> cast(AU as string)) AND ('order_date <=> cast(2024-07-13 as date)))) OR (('country <=> cast(IN as string)) AND ('order_date <=> cast(2023-06-08 as date)))) OR (('country <=> cast(IN as string)) AND ('order_date <=> cast(2024-01-19 as date)))) OR (('country <=> cast(UK as string)) AND ('order_date <=> cast(2024-02-17 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2023-03-30 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2024-07-18 as date)))) OR (('country <=> cast(US as string)) AND ('order_date <=> cast(2023-07-12 as date)))) OR (('country <=> cast(US as string)) AND ('order_date <=> cast(2023-09-04 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2023-07-22 as date)))) OR (('country <=> cast(US as string)) AND ('order_date <=> cast(2023-07-07 as date)))) OR (('country <=> cast(AU as string)) AND ('order_date <=> cast(2024-12-15 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2023-04-05 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2024-09-26 as date)))) OR (('country <=> cast(IN as string)) AND ('order_date <=> cast(2023-04-13 as date)))) OR (('country <=> cast(AU as string)) AND ('order_date <=> cast(2024-04-16 as date)))) OR (('country <=> cast(IN as string)) AND ('order_date <=> cast(2023-04-05 as date)))) OR (('country <=> cast(AU as string)) AND ('order_date <=> cast(2024-01-14 as date)))) OR (('country <=> cast(US as string)) AND ('order_date <=> cast(2024-04-09 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2024-09-29 as date)))) OR (('country <=> cast(AU as string)) AND ('order_date <=> cast(2023-03-29 as date)))) OR (('country <=> cast(UK as string)) AND ('order_date <=> cast(2024-12-26 as date)))) OR (('country <=> cast(US as string)) AND ('order_date <=> cast(2024-08-02 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2024-03-03 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2023-05-31 as date)))) OR (('country <=> cast(AU as string)) AND ('order_date <=> cast(2024-07-06 as date)))) OR (('country <=> cast(AU as string)) AND ('order_date <=> cast(2023-10-04 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2023-11-14 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2024-09-23 as date)))) OR (('country <=> cast(IN as string)) AND ('order_date <=> cast(2023-10-06 as date)))) OR (('country <=> cast(IN as string)) AND ('order_date <=> cast(2023-05-31 as date)))) OR (('country <=> cast(US as string)) AND ('order_date <=> cast(2024-11-07 as date)))) OR (('country <=> cast(US as string)) AND ('order_date <=> cast(2024-02-18 as date)))) OR (('country <=> cast(US as string)) AND ('order_date <=> cast(2024-04-17 as date)))) OR (('country <=> cast(UK as string)) AND ('order_date <=> cast(2023-10-23 as date)))) OR (('country <=> cast(IN as string)) AND ('order_date <=> cast(2024-02-22 as date)))) OR (('country <=> cast(UK as string)) AND ('order_date <=> cast(2023-05-23 as date)))) OR (('country <=> cast(UK as string)) AND ('order ...
# |20     |2025-12-01 17:28:58|72975796256166|bhavithapuli4@gmail.com|UPDATE   |{predicate -> ["(amount#33341 < 50.0)"]}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# |19     |2025-12-01 17:24:34|72975796256166|bhavithapuli4@gmail.com|OPTIMIZE |{clusterBy -> [], zOrderBy -> [], batchId -> 0, predicate -> ["((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((('country <=> cast(CA as string)) AND ('order_date <=> cast(2023-12-27 as date))) OR (('country <=> cast(IN as string)) AND ('order_date <=> cast(2024-06-12 as date)))) OR (('country <=> cast(IN as string)) AND ('order_date <=> cast(2023-10-13 as date)))) OR (('country <=> cast(IN as string)) AND ('order_date <=> cast(2023-08-07 as date)))) OR (('country <=> cast(UK as string)) AND ('order_date <=> cast(2024-12-20 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2024-08-23 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2023-02-07 as date)))) OR (('country <=> cast(AU as string)) AND ('order_date <=> cast(2024-07-13 as date)))) OR (('country <=> cast(IN as string)) AND ('order_date <=> cast(2023-06-08 as date)))) OR (('country <=> cast(IN as string)) AND ('order_date <=> cast(2024-01-19 as date)))) OR (('country <=> cast(UK as string)) AND ('order_date <=> cast(2024-02-17 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2023-03-30 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2024-07-18 as date)))) OR (('country <=> cast(US as string)) AND ('order_date <=> cast(2023-07-12 as date)))) OR (('country <=> cast(US as string)) AND ('order_date <=> cast(2023-09-04 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2023-07-22 as date)))) OR (('country <=> cast(US as string)) AND ('order_date <=> cast(2023-07-07 as date)))) OR (('country <=> cast(AU as string)) AND ('order_date <=> cast(2024-12-15 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2023-04-05 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2024-09-26 as date)))) OR (('country <=> cast(IN as string)) AND ('order_date <=> cast(2023-04-13 as date)))) OR (('country <=> cast(AU as string)) AND ('order_date <=> cast(2024-04-16 as date)))) OR (('country <=> cast(IN as string)) AND ('order_date <=> cast(2023-04-05 as date)))) OR (('country <=> cast(AU as string)) AND ('order_date <=> cast(2024-01-14 as date)))) OR (('country <=> cast(US as string)) AND ('order_date <=> cast(2024-04-09 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2024-09-29 as date)))) OR (('country <=> cast(AU as string)) AND ('order_date <=> cast(2023-03-29 as date)))) OR (('country <=> cast(UK as string)) AND ('order_date <=> cast(2024-12-26 as date)))) OR (('country <=> cast(US as string)) AND ('order_date <=> cast(2024-08-02 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2024-03-03 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2023-05-31 as date)))) OR (('country <=> cast(AU as string)) AND ('order_date <=> cast(2024-07-06 as date)))) OR (('country <=> cast(AU as string)) AND ('order_date <=> cast(2023-10-04 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2023-11-14 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2024-09-23 as date)))) OR (('country <=> cast(IN as string)) AND ('order_date <=> cast(2023-10-06 as date)))) OR (('country <=> cast(IN as string)) AND ('order_date <=> cast(2023-05-31 as date)))) OR (('country <=> cast(US as string)) AND ('order_date <=> cast(2024-11-07 as date)))) OR (('country <=> cast(US as string)) AND ('order_date <=> cast(2024-02-18 as date)))) OR (('country <=> cast(US as string)) AND ('order_date <=> cast(2024-04-17 as date)))) OR (('country <=> cast(UK as string)) AND ('order_date <=> cast(2023-10-23 as date)))) OR (('country <=> cast(IN as string)) AND ('order_date <=> cast(2024-02-22 as date)))) OR (('country <=> cast(UK as string)) AND ('order_date <=> cast(2023-05-23 as date)))) OR (('country <=> cast(UK as string)) AND ('order ...
# |18     |2025-12-01 17:24:29|72975796256166|bhavithapuli4@gmail.com|UPDATE   |{predicate -> ["(amount#31475 < 50.0)"]}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# ...
# |7      |2025-12-01 17:13:52|72975796256166|bhavithapuli4@gmail.com|OPTIMIZE |{clusterBy -> [], zOrderBy -> [], batchId -> 0, predicate -> ["((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((((('country <=> cast(CA as string)) AND ('order_date <=> cast(2023-12-27 as date))) OR (('country <=> cast(IN as string)) AND ('order_date <=> cast(2024-06-12 as date)))) OR (('country <=> cast(IN as string)) AND ('order_date <=> cast(2023-10-13 as date)))) OR (('country <=> cast(IN as string)) AND ('order_date <=> cast(2023-08-07 as date)))) OR (('country <=> cast(UK as string)) AND ('order_date <=> cast(2024-12-20 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2024-08-23 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2023-02-07 as date)))) OR (('country <=> cast(AU as string)) AND ('order_date <=> cast(2024-07-13 as date)))) OR (('country <=> cast(IN as string)) AND ('order_date <=> cast(2023-06-08 as date)))) OR (('country <=> cast(IN as string)) AND ('order_date <=> cast(2024-01-19 as date)))) OR (('country <=> cast(UK as string)) AND ('order_date <=> cast(2024-02-17 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2023-03-30 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2024-07-18 as date)))) OR (('country <=> cast(US as string)) AND ('order_date <=> cast(2023-07-12 as date)))) OR (('country <=> cast(US as string)) AND ('order_date <=> cast(2023-09-04 as date)))) OR (('country <=> cast(UK as string)) AND ('order_date <=> cast(2024-08-26 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2023-07-22 as date)))) OR (('country <=> cast(US as string)) AND ('order_date <=> cast(2023-07-07 as date)))) OR (('country <=> cast(AU as string)) AND ('order_date <=> cast(2024-12-15 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2023-04-05 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2024-09-26 as date)))) OR (('country <=> cast(IN as string)) AND ('order_date <=> cast(2023-04-13 as date)))) OR (('country <=> cast(AU as string)) AND ('order_date <=> cast(2024-04-16 as date)))) OR (('country <=> cast(IN as string)) AND ('order_date <=> cast(2023-04-05 as date)))) OR (('country <=> cast(AU as string)) AND ('order_date <=> cast(2024-01-14 as date)))) OR (('country <=> cast(US as string)) AND ('order_date <=> cast(2024-04-09 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2024-09-29 as date)))) OR (('country <=> cast(AU as string)) AND ('order_date <=> cast(2023-03-29 as date)))) OR (('country <=> cast(UK as string)) AND ('order_date <=> cast(2024-12-26 as date)))) OR (('country <=> cast(US as string)) AND ('order_date <=> cast(2024-08-02 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2024-03-03 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2023-05-31 as date)))) OR (('country <=> cast(AU as string)) AND ('order_date <=> cast(2024-07-06 as date)))) OR (('country <=> cast(AU as string)) AND ('order_date <=> cast(2023-10-04 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2023-11-14 as date)))) OR (('country <=> cast(CA as string)) AND ('order_date <=> cast(2024-09-23 as date)))) OR (('country <=> cast(IN as string)) AND ('order_date <=> cast(2023-10-06 as date)))) OR (('country <=> cast(IN as string)) AND ('order_date <=> cast(2023-05-31 as date)))) OR (('country <=> cast(US as string)) AND ('order_date <=> cast(2024-11-07 as date)))) OR (('country <=> cast(US as string)) AND ('order_date <=> cast(2024-02-18 as date)))) OR (('country <=> cast(US as string)) AND ('order_date <=> cast(2024-04-17 as date)))) OR (('country <=> cast(UK as string)) AND ('order_date <=> cast(2023-10-23 as date)))) OR (('country <=> cast(IN as string)) AND ('order_date <=> cast(2024-02-22 as date)))) OR (('country <=> cast(UK as string)) AND ('ord ...
# +-------+-------------------+--------------+-----------------------+---------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# only showing top 20 rows
# +---------+-------------------+-----------+-------+--------+-------+---------+----------+
# |order_id |order_timestamp    |customer_id|country|currency|amount |status   |order_date|
# +---------+-------------------+-----------+-------+--------+-------+---------+----------+
# |ORD100624|2023-08-30 17:21:45|CUST7053   |CA     |CAD     |664.44 |PAID     |2023-08-30|
# |ORD103901|2023-08-30 21:28:41|CUST9069   |CA     |CAD     |3686.94|CREATED  |2023-08-30|
# |ORD108982|2023-08-30 23:13:18|CUST1852   |CA     |CAD     |3142.54|CANCELLED|2023-08-30|
# |ORD109461|2023-08-30 20:13:02|CUST8972   |CA     |CAD     |3377.06|PAID     |2023-08-30|
# |ORD109946|2023-05-18 12:01:20|CUST8371   |IN     |INR     |3490.06|CANCELLED|2023-05-18|
# |ORD103629|2023-05-18 00:18:40|CUST8453   |IN     |INR     |3121.65|CANCELLED|2023-05-18|
# |ORD102739|2023-05-18 11:47:01|CUST5274   |IN     |INR     |2884.98|PAID     |2023-05-18|
# |ORD101595|2023-05-18 12:43:46|CUST1955   |IN     |INR     |4236.83|CANCELLED|2023-05-18|
# |ORD101016|2023-10-05 02:41:35|CUST4833   |CA     |CAD     |659.03 |CREATED  |2023-10-05|
# |ORD105652|2023-10-05 04:04:39|CUST5390   |CA     |CAD     |2641.8 |CREATED  |2023-10-05|
# |ORD105848|2023-10-05 03:49:42|CUST1400   |CA     |CAD     |2005.49|PAID     |2023-10-05|
# |ORD108975|2023-10-05 21:59:28|CUST1624   |CA     |CAD     |1695.58|CREATED  |2023-10-05|
# |ORD103563|2024-06-09 14:21:54|CUST9345   |CA     |CAD     |2237.94|CREATED  |2024-06-09|
# |ORD106511|2024-06-09 12:43:14|CUST3901   |CA     |CAD     |4124.83|CANCELLED|2024-06-09|
# |ORD109071|2024-06-09 17:42:09|CUST4844   |CA     |CAD     |902.67 |CREATED  |2024-06-09|
# |ORD100971|2023-11-11 22:37:37|CUST5094   |IN     |INR     |1914.98|CANCELLED|2023-11-11|
# |ORD102968|2023-11-11 09:07:21|CUST5834   |IN     |INR     |577.84 |PAID     |2023-11-11|
# |ORD106205|2023-11-11 10:26:29|CUST8631   |IN     |INR     |482.87 |CREATED  |2023-11-11|
# |ORD103864|2023-09-23 22:02:00|CUST8732   |IN     |INR     |3087.68|CREATED  |2023-09-23|
# |ORD104268|2023-09-23 08:17:45|CUST9865   |IN     |INR     |1087.86|CANCELLED|2023-09-23|
# +---------+-------------------+-----------+-------+--------+-------+---------+----------+
# only showing top 20 rows
# +---------+-------------------+-----------+-------+--------+-------+---------+----------+
# |order_id |order_timestamp    |customer_id|country|currency|amount |status   |order_date|
# +---------+-------------------+-----------+-------+--------+-------+---------+----------+
# |ORD109581|2023-01-09 15:45:30|CUST4065   |AU     |AUD     |3299.17|CANCELLED|2023-01-09|
# |ORD100980|2023-01-09 19:32:02|CUST9676   |AU     |AUD     |1128.7 |CANCELLED|2023-01-09|
# |ORD108563|2023-01-05 02:13:15|CUST7393   |AU     |AUD     |3543.51|PAID     |2023-01-05|
# |ORD106457|2023-01-05 06:57:46|CUST5273   |AU     |AUD     |457.79 |PAID     |2023-01-05|
# |ORD100396|2023-01-05 03:36:00|CUST7470   |AU     |AUD     |2615.66|PAID     |2023-01-05|
# |ORD105561|2023-01-06 20:34:12|CUST3152   |AU     |AUD     |2729.22|PAID     |2023-01-06|
# |ORD100487|2023-01-06 00:57:28|CUST3003   |AU     |AUD     |2682.85|PAID     |2023-01-06|
# |ORD102559|2023-01-07 12:38:00|CUST6348   |AU     |AUD     |743.42 |CANCELLED|2023-01-07|
# |ORD102691|2023-01-07 13:21:25|CUST6754   |AU     |AUD     |2329.26|PAID     |2023-01-07|
# |ORD108903|2023-01-04 12:54:14|CUST6936   |AU     |AUD     |4970.21|CANCELLED|2023-01-04|
# |ORD106695|2023-01-06 22:01:49|CUST1901   |AU     |AUD     |490.51 |PAID     |2023-01-06|
# |ORD107584|2023-01-06 00:47:03|CUST6510   |AU     |AUD     |387.09 |PAID     |2023-01-06|
# |ORD103603|2023-01-09 18:52:46|CUST6631   |AU     |AUD     |4745.4 |PAID     |2023-01-09|
# |ORD107282|2023-01-09 19:43:51|CUST6187   |AU     |AUD     |2180.63|PAID     |2023-01-09|
# |ORD105485|2023-01-02 09:02:17|CUST2429   |AU     |AUD     |634.56 |PAID     |2023-01-02|
# |ORD102514|2023-01-02 07:43:50|CUST3944   |AU     |AUD     |3665.23|PAID     |2023-01-02|
# |ORD104690|2023-01-01 10:12:31|CUST5498   |AU     |AUD     |1892.24|CANCELLED|2023-01-01|
# |ORD105443|2023-01-04 13:52:15|CUST7166   |AU     |AUD     |1148.52|PAID     |2023-01-04|
# |ORD101792|2023-01-05 03:11:03|CUST9374   |AU     |AUD     |1913.98|PAID     |2023-01-05|
# |ORD106113|2023-01-07 11:40:10|CUST4281   |AU     |AUD     |552.84 |PAID     |2023-01-07|
# +---------+-------------------+-----------+-------+--------+-------+---------+----------+
# only showing top 20 rows

# %%
#7.Demonstrate Schema Evolution by adding new columns
df.printSchema()
# Out:
# root
#  |-- order_id: string (nullable = true)
#  |-- order_timestamp: timestamp (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- currency: string (nullable = true)
#  |-- amount: double (nullable = true)
#  |-- status: string (nullable = true)
#  |-- order_date: date (nullable = true)

# %%
from pyspark.sql.functions import col, lit, when, rand
df_new = (
    df
    # Add payment_method column
    .withColumn(
        "payment_method",
        when(col("status") == "CREATED", "NOT COMPLETED")
        .when(
            col("status") == "CANCELLED",
            when(rand() < 0.5, "REFUNDED").otherwise(lit(None))
        )
        .when(
            col("status") == "PAID",
            when(col("amount") < 1000,
                 when(rand() < 0.6, "COD").otherwise("UPI"))
            .when(col("amount") < 4000,
                  when(rand() < 0.3, "COD")
                  .when(rand() < 0.5, "UPI")
                  .otherwise("CARD"))
            .otherwise(
                when(rand() < 0.4, "UPI").otherwise("CARD")
            )
        )
        .otherwise(lit(None))
    )
    # Add coupon_code column
    .withColumn(
        "coupon_code",
        when(col("amount") >= 3000, "SAVE300")
        .when(col("amount") >= 1500, "SAVE150")
        .when(col("amount") >= 500, "FLAT50")
        .otherwise(lit(None))
    )
)
df_new.printSchema()
# Out:
# root
#  |-- order_id: string (nullable = true)
#  |-- order_timestamp: timestamp (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- currency: string (nullable = true)
#  |-- amount: double (nullable = true)
#  |-- status: string (nullable = true)
#  |-- order_date: date (nullable = true)
#  |-- payment_method: string (nullable = true)
#  |-- coupon_code: string (nullable = true)

# %%
#Writing new data to the Delta table with schema evolution
df_new.write \
    .format("delta") \
    .mode("append") \
    .option("mergeSchema", "true") \
    .saveAsTable("chubb.default.orders")

# %%
#8.1 Demonstrate Delta Lake UPDATE.
#Cancel orders where amount is between 50 and 200
updated_rows = delta.update(
    condition="amount >= 50 AND amount <= 200",   
    set={"status": "'CANCELLED'"}
)

# %%
#8.2 Demonstrate Delta Lake DELETE operation.
#Deleting the record where amount<210
deleted_rows = delta.delete(
    condition="amount < 210"
)

# %%
#Creating RAW (Unoptimized) Delta Table Using saveAsTable
import time
# Create RAW table (unoptimized)
start_write = time.time()
df.write.format("delta") \
    .mode("overwrite") \
    .saveAsTable("chubb.default.orders_raw")
end_write = time.time()
# Print the elapsed time for the operation.
# This acts as a measurement before optimization
print("RAW table created as chubb.default.orders_raw")
print("Time taken to write RAW table:", end_write - start_write)
# Out:
# RAW table created as chubb.default.orders_raw
# Time taken to write RAW table: 3.3099515438079834

# %%
#9.Use OPTIMIZE and optionally ZORDER on customer_id or order_date
spark.sql("""OPTIMIZE chubb.default.orders_raw""")
print("OPTIMIZE completed.")
# ZORDER on customer_id
spark.sql("""OPTIMIZE chubb.default.orders_raw ZORDER BY (customer_id)""")
print("ZORDER BY customer_id completed.")
# Out:
# OPTIMIZE completed.
# ZORDER BY customer_id completed.

# %%
#10.show how small file problems can occur with too many partitions and how OPTIMIZE helps.
detail_df = spark.sql("DESCRIBE DETAIL chubb.default.orders_raw")
detail_df.select("numFiles", "sizeInBytes").show(truncate=False)
# Out:
# +--------+-----------+
# |numFiles|sizeInBytes|
# +--------+-----------+
# |1       |269653     |
# +--------+-----------+

# %%
import time
start = time.time()
spark.sql("SELECT COUNT(*) FROM chubb.default.orders_raw").collect()
end = time.time()

print("Time AFTER OPTIMIZE:", end - start)
# Out:
# Time AFTER OPTIMIZE: 0.45029187202453613
